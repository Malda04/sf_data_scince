# %% [markdown]
# # Игра "Угадай число"

# %% [markdown]
# ## Угадываем рандомно

# %%
from game_v2 import score_game, random_predict

# %%
score_game(random_predict)
# Out:
# Загадано число от 1 до 100
# Угадываемое число меньше 50
# Алгоритм бинарного поиска рекомендует вам число:25
# Угадываемое число больше 25
# Алгоритм бинарного поиска рекомендует вам число:38
# Загадано число от 1 до 100
# Угадываемое число меньше 50
# Алгоритм бинарного поиска рекомендует вам число:25
# Угадываемое число меньше 25
# Алгоритм бинарного поиска рекомендует вам число:12
# Угадываемое число больше 12
# Алгоритм бинарного поиска рекомендует вам число:18
# Угадываемое число меньше 18
# Алгоритм бинарного поиска рекомендует вам число:15
# Угадываемое число меньше 15
# Алгоритм бинарного поиска рекомендует вам число:14
# Угадываемое число меньше 14
# Алгоритм бинарного поиска рекомендует вам число:13
# Загадано число от 1 до 100
# Угадываемое число больше 50
# Алгоритм бинарного поиска рекомендует вам число:75
# Угадываемое число меньше 75
# Алгоритм бинарного поиска рекомендует вам число:62
# Угадываемое число больше 62
# Алгоритм бинарного поиска рекомендует вам число:68
# ...
